# %%
import pandas as pd
import numpy as np
# initial dataframe with random numbers
np.random.seed(123)
M = 100
N = 1000
raw_df = pd.DataFrame(np.array([(np.random.choice([f'index_{i}' for i in range(1,5)]), 
                                 *[np.random.randint(1000) for i in range(M)]) for n in range(N)]),
columns=['index', *range(M)])
raw_df.set_index('index', inplace = True)
raw_df
# Out:
#           0    1    2    3    4    5    6   ...   93   94   95   96   97   98   99
# index                                       ...
# index_3  365  382  322  988   98  742   17  ...  537  434  980  824  305  780  530
# index_2  513   51  940  885  745  304   56  ...  959   58  493   77    8  206  390
# index_2  222  198  552  887  970   76  460  ...  944  771  791  731  695  290  293
# index_2  855  853  665  401  186  194  301  ...  495  896  803  881   83  350  583
# index_4  855  501  851  886  334   29   19  ...  288  414  771  735  233  219  247
# ...      ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# index_3  228  231  477  523  906  915  226  ...  995  925  566  701  582   80  534
# index_4   72  806  345  192  589   81  255  ...  224  130  500  854  428  194  439
# index_4  420  921  852  118  959  709  100  ...  906  347  421  369  937  973  133
# index_1  974  260  909  308  318   58  858  ...  978  426  908  980  233  817  241
# index_3  976  880  367  542  272  873  458  ...  888   78  253  926  180  575  723
#
# [1000 rows x 100 columns]

# %%
df1 = raw_df.stack().groupby(level=[0]).value_counts().unstack(1, fill_value=0)
df1
# Out:
#           0   1  10  100  101  102  103  ...  993  994  995  996  997  998  999
# index                                    ...
# index_1  19  19  24   17   25   32   25  ...   25   22   21   16   19   24   31
# index_2  26  29  31   28   16   24   15  ...   17   34   22   26   38   38   19
# index_3  24  23  25   15   27   21   22  ...   21   25   23   17   23   24   22
# index_4  41  21  29   18   19   16   30  ...   29   24   26   30   33   33   37
#
# [4 rows x 1000 columns]

# %%
df1 = df1.reindex(sorted(df1.columns), axis=1)
print(len(df1))
df1
# Out:
# 4
#           0   1  10  100  101  102  103  ...  993  994  995  996  997  998  999
# index                                    ...
# index_1  19  19  24   17   25   32   25  ...   25   22   21   16   19   24   31
# index_2  26  29  31   28   16   24   15  ...   17   34   22   26   38   38   19
# index_3  24  23  25   15   27   21   22  ...   21   25   23   17   23   24   22
# index_4  41  21  29   18   19   16   30  ...   29   24   26   30   33   33   37
#
# [4 rows x 1000 columns]

# %%
p = list(range(0,1000))
for i in range(0, len(p)): 
    p[i] = str(p[i])

# %%
df1.reindex(columns=p)
# Out:
#           0   1   2   3   4   5   6   7  ...  992  993  994  995  996  997  998  999
# index                                    ...
# index_1  19  19  29  30  19  25  20  17  ...   23   25   22   21   16   19   24   31
# index_2  26  29  32  18  18  22  24  22  ...   28   17   34   22   26   38   38   19
# index_3  24  23  32  36  22  18  24  23  ...   25   21   25   23   17   23   24   22
# index_4  41  21  24  28  26  33  28  29  ...   36   29   24   26   30   33   33   37
#
# [4 rows x 1000 columns]
